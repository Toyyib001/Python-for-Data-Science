# %%
import numpy as np
import pandas as pd

# %%
dt = pd.read_csv('https://raw.githubusercontent.com/Tiamiyu1/Python-for-Data-Science-and-Analytics/main/Data/supermarket_data.csv')
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# Which City has the highest customers? Yangon City

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(25,10))
sns.countplot(dt['City'])
plt.title('Countplot of City')
plt.xlabel('City')
plt.ylabel('No of Customers')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'No of Customers')

# %%
plt.figure(figsize=(25,10))
sns.countplot(dt['Gender'])
plt.title('Countplot of Gender')
plt.xlabel('City')
plt.ylabel('No of Customers')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'No of Customers')

# %% [markdown]
# Which gender has the highest count in each of the Cities/Stores?

# %% [markdown]
# IN YANGON CITY

# %%
dty=dt[dt['City'] == 'Yangon']

# %%
sns.countplot(dty.Gender)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In Yangon, it was gotten to be the male that has the higher count

# %% [markdown]
# In Naypyitaw City

# %%
dtn=dt[dt['City'] == 'Naypyitaw']
sns.countplot(dtn.Gender)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In Naypyitaw, it was gotten to be the female that has the higher count

# %% [markdown]
# In Mandalay	City

# %%
dtm=dt[dt['City'] == 'Mandalay']
sns.countplot(dtn.Gender)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In Mandalay, it was gotten to be the male that has the higher count

# %% [markdown]
# What product has the highest sales?

# %%
plt.figure(figsize = (10,5))
sns.countplot(dt['Product line'])
plt.xticks(rotation = 45)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# Fashion accessories	has the highest product sales

# %% [markdown]
# What product was bought most male?

# %%
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dtm = dt[dt['Gender'] == 'Male']
plt.figure(figsize = (10,5))
sns.countplot(dtm['Product line'])
plt.xticks(rotation = 45)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# Health and beauty has the most sale

# %% [markdown]
# What product was bought most female?

# %%
dtf = dt[dt['Gender'] == 'Female']
plt.figure(figsize = (10,5))
sns.countplot(dtf['Product line'])
plt.xticks(rotation = 45)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# Fashion accessories have the most sales for the female gender

# %% [markdown]
# Which product has the highest average rating?

# %%
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dt.Rating.max()
# Out:
# 10.0

# %%
dt[dt.Rating == 10.0]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 60   285-68-5083      C  Naypyitaw        Member  Female
# 62   347-34-2234      B   Mandalay        Member  Female
# 159  423-57-2993      B   Mandalay        Normal    Male
# 387  725-56-0833      A     Yangon        Normal  Female
# 853  866-70-2814      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 60        Sports and travel       24.74         3   3.7110   77.9310
# 62        Sports and travel       55.07         9  24.7815  520.4115
# 159       Sports and travel       93.39         6  28.0170  588.3570
# 387       Health and beauty       32.32        10  16.1600  339.3600
# 853  Electronic accessories       52.79        10  26.3950  554.2950
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 60   2/15/2019  17:47  Credit card   74.22                 4.761905
# ...

# %% [markdown]
# Sports and travel	has the highest average rating

# %% [markdown]
# Who gives the highest average rating, male or female?

# %% [markdown]
# Female

# %% [markdown]
# Which customer type dominate each city/store?

# %%
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dt.value_counts('Customer type')
# Out:
# Customer type
# Member    501
# Normal    499
# dtype: int64

# %%
dtm.value_counts('Customer type')
# Out:
# Customer type
# Normal    259
# Member    240
# dtype: int64

# %%
sns.countplot(dtm['Customer type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Customer type 'Normal' dominates Mandalav

# %%
dty.value_counts('Customer type')
# Out:
# Customer type
# Normal    173
# Member    167
# dtype: int64

# %%
sns.countplot(dty['Customer type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Customer type 'Normal' dominates Yangon

# %%
dtn.value_counts('Customer type')
# Out:
# Customer type
# Normal    167
# Member    165
# dtype: int64

# %%
sns.countplot(dtn['Customer type'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Customer type 'Normal' dominates Yangon

# %% [markdown]
# What month of the year has the highest sales?

# %%
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import datetime

# %%
dt['Date'] = pd.to_datetime(dt['Date'])
dt['Time'] = pd.to_datetime(dt['Time'])

# %%
dt['Month'] = dt['Date'].dt.month

# %%
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dt.value_counts('Month')
# Out:
# Month
# 1    352
# 3    345
# 2    303
# dtype: int64

# %%
sns.countplot(dt['Month'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The highest number of sales occurred at Month 1

# %% [markdown]
# What month of the year has the highest gross income?

# %%
dt['gross income'].max()
# Out:
# 49.65

# %%
dtG = dt[dt['gross income'] == 49.65]
dtG
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date                Time  \
# 350        99.3        10   49.65  1042.65 2019-02-15 2022-05-15 14:53:00
#
#          Payment   cogs  gross margin percentage  gross income  Rating  Month
# 350  Credit card  993.0                 4.761905         49.65     6.6      2

# %% [markdown]
# The highest gross income occurred at the month of February

# %% [markdown]
# Who spend most on average, male or female?

# %%
dt['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
dt.value_counts('Gender')
# Out:
# Gender
# Female    501
# Male      499
# dtype: int64

# %%
sns.countplot(dt.Gender)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The female gender spends most.

# %% [markdown]
# Which hour of the day has the highest sales?

# %%
dt['Hour'] = dt['Time'].dt.hour

# %%
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dt.value_counts('Hour')
# Out:
# Hour
# 19    113
# 13    103
# 15    102
# 10    101
# 18     93
# 11     90
# 12     89
# 14     83
# 16     77
# 20     75
# 17     74
# dtype: int64

# %%
sns.countplot(dt['Hour'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# The highest sale occurred at the 19th hour of the day

# %% [markdown]
# What is the min quantity ever purchased?

# %%
dt['Quantity'].min()
# Out:
# 1

# %% [markdown]
# The minimum quantity is just one.

# %% [markdown]
# What payment method is used most by each gender?

# %%
dt.value_counts('Payment')
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# dtype: int64

# %%
sns.countplot(dt.Payment)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Ewallet was mostly used

# %% [markdown]
# What payment method is used most by each customer type?

# %%
dt
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dtN = dt[dt['Customer type'] == 'Normal']

# %%
dtN
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
dtN.Payment.value_counts()
# Out:
# Ewallet        184
# Cash           176
# Credit card    139
# Name: Payment, dtype: int64

# %%
sns.countplot(dtN['Payment'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Customer type 'Normal' is mostly fond of using by Ewallet

# %%
dtMember = dt[dt['Customer type'] == 'Member']

# %%
dtMember
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 3    123-19-1176      A     Yangon        Member    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 989  430-53-4718      B   Mandalay        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 3         Health and beauty       58.22         8  23.2880  489.0480
# 6    Electronic accessories       68.84         6  20.6520  433.6920
# ...

# %%
dtMember.Payment.value_counts()
# Out:
# Credit card    172
# Cash           168
# Ewallet        161
# Name: Payment, dtype: int64

# %%
sns.countplot(dtMember['Payment'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Customer type 'Member' is mostly fond of using Credit card

# %% [markdown]
# What is the average rating for each of the stores/cities?

# %%
dt

# %%
dtm
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 9    692-92-5582      B  Mandalay        Member  Female
# 10   351-62-0822      B  Mandalay        Member  Female
# 11   529-56-3974      B  Mandalay        Member    Male
# 15   299-46-1805      B  Mandalay        Member  Female
# 19   319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 987  552-44-5977      B  Mandalay        Member    Male
# 989  430-53-4718      B  Mandalay        Member    Male
# 991  602-16-6955      B  Mandalay        Normal  Female
# 993  690-01-6631      B  Mandalay        Normal    Male
# 996  303-96-2227      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Total  \
# 9        Food and beverages       54.84         3   8.226   172.746
# 10      Fashion accessories       14.48         4   2.896    60.816
# 11   Electronic accessories       25.51         4   5.102   107.142
# ...

# %%
dtm.Rating.mean()
# Out:
# 6.8180722891566266

# %% [markdown]
# The average rating is 6.8180722891566266 for Mandalay City

# %% [markdown]
# Yangon City

# %%
dty
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
dty.Rating.mean()
# Out:
# 7.027058823529413

# %% [markdown]
# The average rating is 7.027058823529413 for Yangon City

# %% [markdown]
# Naypyitaw City

# %%
dtn
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 20   300-71-4605      C  Naypyitaw        Member    Male
# 34   183-56-6882      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 984  189-40-5216      C  Naypyitaw        Normal    Male
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 995  233-67-5758      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 5    Electronic accessories       85.39         7  29.8865  627.6165
# 7        Home and lifestyle       73.56        10  36.7800  772.3800
# ...

# %%
dtn.Rating.mean()
# Out:
# 7.072865853658538

# %% [markdown]
# The average rating is 7.072865853658538 for Naypyitaw City

# %% [markdown]
# What is the average rating for each of the product lines?

# %% [markdown]
# For Electronic accessories;

# %%
dtElectronic = dt[dt['Product line'] == 'Electronic accessories']
dtElectronic.Rating.mean()
# Out:
# 6.92470588235294

# %% [markdown]
# The average rating is 6.92470588235294 for Electronic accessories

# %% [markdown]
# For Health and beauty

# %%
dtHealth = dt[dt['Product line'] == 'Health and beauty']
dtHealth.Rating.mean()
# Out:
# 7.003289473684212

# %% [markdown]
# The average rating is 7.003289473684212 for Health and beauty

# %% [markdown]
# For Food and beverages;

# %%
dtFood = dt[dt['Product line'] == 'Food and beverages']
dtFood.Rating.mean()
# Out:
# 7.113218390804598

# %% [markdown]
# The average rating is 7.113218390804598 for Food and beverages

# %%
dtHome = dt[dt['Product line'] == 'Home and lifestyle']
dtHome.Rating.mean()
# Out:
# 6.8375

# %% [markdown]
# The average rating is 6.8375 for Home and lifestyle
